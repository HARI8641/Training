# %%
print("hello excel")

# %%
import polars as pl, pandas as pd

# %%
df = pl.read_csv(r"D:\data\_cleaned_data_BrandA_Data_Loyalty_NonLoyalty.csv", ignore_errors=True)

# %%
df.columns

# %%
# Summing a boolean True/False list counts the True values
one_time_customers = df["customer_id"].is_unique().sum()
print(one_time_customers)

# %%
df['customer_id'].n_unique()

# %%
df['customer_id'].is_duplicated().sum()

# %%
df.shape

# %%
527283 - 542419

# %%
df['total_spend'].sum()

# %%
df['currentTier'].value_counts()
