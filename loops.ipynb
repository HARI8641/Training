# %%
print(
    "hello loops!"
)

# %%
lock = 002
num = 000
if num == lock:
    print('password cracked')
elif num >= lock:
    print('try better')
else:
    print('lets try tommorow')

# %%
# Demonstrating break and continue
num = 0
while num < 10:
    num += 1
    
    if num == 5:
        continue  # Skip printing 5
    
    if num == 8:
        break  # Stop loop when num is 8
    
    print(num)

# %%
winner = 1
while (winner <= 151):
    print(f"{winner} -> run ")
    winner = winner + 1

# %%
winner = 1
while (winner <= 151):
    print(f"{winner} -> run ")
    winner = winner + 1
else:
    print("it's Done")

# %%
celing =  int(input())
floor = int(input())
count = 0
while (celing <= floor):
    print(f'celing : {celing}')
    print(f'floor : {floor}')
    count = count + 1
print(count)

# %%
celing = int(input('celing would be:'))
floor = int(input('floor would be:'))

while celing<= floor:
    print("celing")

# %%
num = int(input('even no is:'))
if num%3:
    print("2 table")
    print(num%3)
else:
    print(num)

# %%
2**3 # power and multiples the value
10%4 # holds the remainder of division

# %%
while True:
    user_input = input("Type 'exit' to quit: ")
    if user_input == 'exit':
        break

# %%
#As a ticket checker i want the rider to have the enough ticket to take the ride
ticket = 5

while ticket > 0:
  ticket = ticket - 1
  print('run')
else:
    print('no more ticket')

# %%
ride = 7
    
while ride > 4 :
    ride = ride - 1
    
    if ride <=4 : 
        ride = int(input('enter the ride:'))
    else:
        print('enjoy the ride')
    
else:
    ride = ride - 1
    print('no more ride')

# %%
#scaler problem in loops moduel:

# %%
n = int(input())

for i in range(1, n + 1):
    print(i)

# %%
n = int(input())

# Loop through numbers from 1 to N
for i in range(1, n + 1):
    if i % 2 == 0:   # Check if even
        print(i, end=" ")
else:
    print("\nDone")

# %%
1%3 !=0

# %%
for i in range(2,10):
    print(i)

# %%
# scaler loop 1 moduel q3
# write code here

a = int(input())
result = []

for i in range(0, 4):
    
    i = 1-a**i
    result.append(str(i))
print(" ".join(result))


#❌code iswrong because the loop is not running properly and the result is not correct. The loop should run from 0 to 3, but it is running from 1 to 4. Also, the calculation of i is not correct. It should be a**i instead of 1-a**i.

# %%
from numpy import append


a = int(input())



i = 1

while i*i < a:
         result = append(str(i*i))
         i += 1
    
print(result, end=" ")
# ✔️fixed the code by changing the loop to a while loop and checking if i*i is less than a. Also, I changed the calculation of i to i*i instead of 1-a**i.

# %%
a = int(input())
result = []

# Start from 1 and increment
i = 1
while i * i <= a:
    # i * i is the perfect square
    result.append(str(i * i))
    i += 1

print(" ".join(result))

# %%
 # 2. Use 'n' as your counter starting at 1
n = 1

# 3. Create a list to store results for space-separated output
results = []

# 4. Loop while the square of n is less than or equal to A
while n * n <= 1000:
    results.append(str(n * n))
    n += 1 # Increment n so the loop eventually ends
    
# 5. Print the squares separated by a space
print(" ".join(results))

# %% [markdown]
# # Scaler d-46 q-04
#
# Q4. for loop output
#
# What will be the output of the following code:
#
# for i in range(-6, -10, -1):
#      print(i, end =" ")
#
# - -6 -7 -8 -9
#
# - -7 -8 -9 -10
#
# - -6 -7 -8 -9 -10
#
# - Infinite loop

# %%
for i in range(-6, -10, -1):
     print(i, end =" ")

# %% [markdown]
# # Scaler d-46 q_01
#
# Q1. arrange while
#
# You want to find the first n natural even numbers. In what sequence should the following statements be rearranged to get the desired output?
# Assume that suitable indentation will be included.
#
# 1. if i%2 ==0:
# 2. i=2
# 3. print(i)
# 4. while (i<=2*n):
# 5. i+=1
#
#
# - 1 3 4 2 5
# - 2 4 1 3 5
# - 2 4 3 1 5
# - 4 2 1 3 5

# %%
i=2
n= 5

while (i<=2*n):
    if i%2 ==0:
            print(i)
    i+=1
