# %%
print("hello")
# Out:
# hello

# %%
###atm 
correct_password = 123456
input_password = int(input())
#pattern = r"^[1-9]{2}[0]{3}$"

if correct_password == input_password:
    print("welcome to secure cash dispensor")
    withdraw = int(input())
    if withdraw%500 == 0:
        print(f"collect the cash ${withdraw}")
    else:
        print(f"faled to dispense the cash ${withdraw}")
    
else:
    print("wrong password, better luck next time")

# %%
numbers = [10, 20, 30, 40, 50, 40]
index = numbers.index(40, 3, 6) # Returns 3
print(index)
# Out:
# 3

# %%
for i in numbers:
    print(i)

print(i>=40)
# Out:
# 10
# 20
# 30
# 40
# 50
# 40
# True

# %%
a = int(input())

if a > 5:
    print("login")
elif a< 5:
    print("check if")
else:
    print("failed login")
# Out:
# check if

# %%
a = input()

pattern = r"^[a-c]{3}[1-9]{2}@gmail.com"

if a (pattern, a):
    print("login")
else:
    print("fail")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       1 a = input()
#       3 pattern = r"^[a-c]{3}[1-9]{2}@gmail.com"
# ----> 5 if a (pattern, a):
#       6     print("login")
#       7 else:
#
# TypeError: 'str' object is not callable

# %%
import re

# Compile once
pattern = re.compile(r"^[A-Z]{3}-\d{4}$")

# Use many times
if pattern.fullmatch("ABC-1234"):
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
# dictionary
price_list = {'apple': 50, 'orange': 60, 'pinapple': 90}

# %%
for i in price_list:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for i in price_list:
#       2     print(i)
#
# NameError: name 'price_list' is not defined

# %%
for j in price_list:
    print(price_list[j])
    print({price_list[j]})
    print({j})
    print(f"{j} -> {price_list[j]}")
    print(f"{j} -> price_list[j]")
# Out:
# 50
# {50}
# {'apple'}
# apple -> 50
# apple -> price_list[j]
# 60
# {60}
# {'orange'}
# orange -> 60
# orange -> price_list[j]
# 90
# {90}
# {'pinapple'}
# pinapple -> 90
# pinapple -> price_list[j]

# %%
price_list.values()
price_list.keys()
price_list.items()

for key, value in price_list.items():
    print(f"{key} - {value}")
# Out:
# apple - 50
# orange - 60
# pinapple - 90

# %%
fruit = price_list.update({'Mango': 100})
price_list
# Out:
# {'apple': 50, 'orange': 60, 'pinapple': 90, 'Mango': 100}

# %%
'mango' in price_list
# Out:
# False

# %% [markdown]
# ###list and indexing
#
# - every list starts from the 0 in the index
# - every lsit is mentione with the parentheses [ ]

# %%
#Step-1 create a list and print the 3rd value in the index
a = [ 15,20,40,50]
a[3]
# Out:
# 50

# %%
#step-2 find the lenght of the list
len(a)
# Out:
# 4

# %%
# negatrive indexing
a[len(a)-3]
# Out:
# 20

# %%
correct_password = 123456
input_password = int(input())
pattern = r"^[1-9]{2}[0]{3}$"

if correct_password == input_password:
    print("welcome to secure cash dispensor")
    withdraw = int(pattern, input())
    if withdraw%500 == 0:
        print(f"collect the cash ${withdraw}")
    else:
        print(f"faled to dispense the cash ${withdraw}")
    
else:
    print("wrong password, better luck next time")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 correct_password = 123456
# ----> 2 input_password = int(input())
#       3 pattern = r"^[1-9]{2}[0]{3}$"
#       5 if correct_password == input_password:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Out:
# welcome to secure cash dispensor
# collect the cash $10000
