# %%
text = "IUCD/Oral pill/Tubectomy/Injectable/Implant/others"

# %%
df = [item.strip().title() for item in text.split('/')]
print(df)
# Out:
# ['Iucd', 'Oral Pill', 'Tubectomy', 'Injectable', 'Implant', 'Others']

# %%
import pandas as pd

x = pd.DataFrame(df, columns=['Education Level'])

# %%
x = pd.DataFrame(df, columns=['Education Level'])
x.to_clipboard(index=False)
