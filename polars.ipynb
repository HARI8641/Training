# %%
print("Hello Polars")

# %%
import polars as pl

# %%
# %%timeit
import pandas as pd

# %%
# %%timeit
df = pl.read_csv(r"C:\Users\rrph8\Downloads\products-2000000.csv")

# %%
# %%timeit
df

# %%
# %%timeit
import pandas as pd

# %%
# %%timeit
ds = pl.read_csv(r"C:\Users\rrph8\Downloads\products-2000000.csv")

# %%
# %%timeit
ds
