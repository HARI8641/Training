# %%
# %pip install polars

# %%
import pandas as pd, numpy as np, polars as pl, os, sys, time, datetime, json, re, math, random, string, logging, argparse

# %%
db = pl.read_csv(r"C:\Users\rrph8\Downloads\pharmacy_inventory_full.csv")

# %%
db.glimpse()

# %%
db = db.to_pandas()

# %%
db
