# %%
print("Hello, functions and permeter")

# %%
name = mass
def greet(name):
    print("Hello, " + name)

print("Before calling the function")
greet(name)

# %%
def report(message):
    print("This is a report: " + message)

# %%
report

# %%
report

# %%
def add(x, y):
    return x + y

# %%
add(2, 3)

# %%
sub(2, 3)

# %%
def greet(x,y):
    return x-y

# %%
greet(5, 2)

# %%
def chaiwala():
    print("Your order is ready")

# %%
tea = 5
for i in range(int(input("How many cups of tea do you want? "))):
    if tea >1:
        print(chaiwala())
    else:
        print("Here is your cup of tea")

# %%
# function definition
def find_square(num):
    result = num * num
    return result

# function call
square = find_square(3)

print('Square:', square)

# %%
help(if)

# %%
help('if')

# %%
help('keywords')
