# %%
print("hello OOPS")

# %%
class Employee:
    def __init__(onroll):
        onroll.name = str(input("Enter name: "))
        onroll.age = int(input("Enter age: "))
        onroll.salary = int(input("Enter salary: "))
    def display(onroll):
        print("Name: ", onroll.name)
        print("Age: ", onroll.age)
        print("Salary: ", onroll.salary)

# %%
hanuman = Employee()
hanuman.salary

# %%
hanuman.age

# %%
hanuman.name

# %%
hanuman.display()

# %%
ravi = Employee()

# %%
ravi.display()

# %% [markdown]
# Scaler Day-59 prob- ad 2

# %%
class football:
    final_res= 'lose'
    def __init__(self,name,score):
        self.name = name
        self.score = score
        self.final_res = 'lose'
    
    def calc(self, winning_score):
        if self.score>winning_score:
            self.final_res='win'
match = football('Juventus',3)
match.calc(2)
print(football.final_res, match.final_res)

# %% [markdown]
# Scaler Day-59 prob- ad 3

# %%
class Student:
    def __init__(self,roll,marks):
        self.roll = roll
        self.marks = marks
    def display(self):
        print('Roll:', self.roll,'Marks:',self.marks, end=" ")

student1 = Student(34,'A')
student1.age = 17
print(student1.display(), 'Age:',student1.age)

# %% [markdown]
# Scaler Day-59 prob- ad 1

# %%
class fruits:
    def __init__(self, price):
        self.price = price

obj=fruits(50)
obj.quantity=10
obj.bags=2

print(obj.quantity+len(obj.__dict__))

# %% [markdown]
# SCaler Day - 59 prob-ad-4
#
# Fill the blanks in the code snippet to get the given output?
#
# class Student:
#   # Class variable
#   subject_name = 'Math for Machine Learning'
#
#   # constructor
#   def __init__(self, name, roll_no):
#     self.name = name
#     self.roll_no = roll_no
#
# # outside the class
# # create Objects
# _____________________#blank1
# _____________________#blank2
#
# print(s1.name, s1.roll_no, s1.subject_name)
#
# Choose the correct option(s) for getting Emma 10 Machine Learning as the output if the blanks are replaced by statements given in the options.
#
#
#
# - s1 = Student('Emma', 10), Student.subject_name = 'Machine Learning'
# - s1 = Student('Emma', 10), s1.subject_name = 'Machine Learning'
# - s1 = Student('Emma', 10), No change required
# - None of the above

# %%
class Student:
  # Class variable
  subject_name = 'Math for Machine Learning'

  # constructor
  def __init__(self, name, roll_no):
    self.name = name
    self.roll_no = roll_no

# outside the class
# create Objects
s1 = Student("Emma", 1001)


print(s1.name, s1.roll_no, s1.subject_name)
# Out:
# Emma 1001 Math for Machine Learning

# %% [markdown]
# SCaler Day - 59 prob-ad-
#
# Q5. class solution
#
# What will be the output of the following code snippet?
#
# class solution:
#   def initial(self,sets):
#     return self.final(sets)
#
#   def final(self, sets):
#     return list(map(lambda x: ((x**3)%2==0,x**3),sets))
#
# print(solution().initial([4,5,6]))
#
#
#
# * [ [ ], [ 4 ], [ 5 ], [ 4, 5 ], [ 6 ], [ 4, 6 ], [ 5, 6 ], [ 4, 5, 6 ] ]
#
# * [(64, True), (125, False), (216, True)]
#
# * [[], [6], [5], [5, 6], [4], [4, 6], [4, 5], [4, 5, 6]]
#
# * [(True, 64), (False, 125), (True, 216)]
#
#
# ![image.png](attachment:image.png)

# %%
class solution:
  def initial(self,sets):
    return self.final(sets)
 
  def final(self, sets):
    return list(map(lambda x: ((x**3)%2==0,x**3),sets))

print(solution().initial([4,5,6]))
# Out:
# [(True, 64), (False, 125), (True, 216)]
