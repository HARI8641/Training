# %%
print("hello file")

# %% [markdown]
# #required library

# %%
import datetime
import time

# %%
current = time.localtime()

# %%
date = datetime.datetime.now()

# %%
def file_name():
    strings = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    return strings

# %%
filename = file_name()

# %%
file_name()

# %%
strings = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %%
date

# %%
current
